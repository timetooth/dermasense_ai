# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import tensorflow as tf
import os
import random

# %%
def transform(image):
    # grayScale = cv.cvtColor( image, cv.COLOR_RGB2GRAY )
    # kernel = cv.getStructuringElement(1,(17,17))
    # blackhat = cv.morphologyEx(grayScale, cv.MORPH_BLACKHAT, kernel)
    # ret,thresh2 = cv.threshold(blackhat,10,255,cv.THRESH_BINARY)
    # image = cv.inpaint(image,thresh2,1,cv.INPAINT_TELEA)
    image_yuv = cv.cvtColor(image, cv.COLOR_RGB2YUV)
    image_yuv[:, :, 0] = cv.equalizeHist(image_yuv[:, :, 0])
    image_equalized = cv.cvtColor(image_yuv, cv.COLOR_YUV2RGB)
    return image_equalized

# %%
root = './train'
buckets = {}
images = []
labels = []

for img_name in os.listdir(root):
    class_img = img_name.split('_')[0]
    if class_img == 'nv': continue
    img = cv.imread(os.path.join(root,img_name))
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img = cv.resize(img, (112, 112))
    img = transform(img)
    if class_img in buckets: buckets[class_img]+=1
    else: buckets[class_img] = 0
    images.append(img)
    labels.append(class_img)

# %%
i = random.randint(0,len(images))
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(images[i])
plt.title(labels[i])
i = random.randint(0,len(images))
plt.subplot(1,2,2)
plt.imshow(images[i])
plt.title(labels[i])
plt.tight_layout()
plt.show()

# %%
print(buckets)
# Out:
# {'bkl': 1098, 'mel': 1112, 'df': 114, 'bcc': 513, 'akiec': 326, 'vasc': 141}

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
labels = le.fit_transform(labels)
images = np.array(images)/255.0
labels = np.array(labels)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
plt.subplot(1,2,1)
i = random.randint(0,len(X_train))
plt.imshow(X_train[i])
plt.title(f'{y_train[i]}, train')
i = random.randint(0,len(X_test))
plt.subplot(1,2,2)
plt.imshow(X_test[i])
plt.title(f'{y_test[i]}, test')
# Out:
# Text(0.5, 1.0, '2, test')

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(112, 112, 3)),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    
    Flatten(),
    Dense(512, activation='relu'),
    Dense(6, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 110, 110, 32)      896
#
#  batch_normalization (Batch  (None, 110, 110, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 55, 55, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 53, 53, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 53, 53, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 26, 26, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 24, 24, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 10, 10, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 512)               1638912
#
#  dense_1 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 1884230 (7.19 MB)
# Trainable params: 1883526 (7.19 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %%
# callbacks = [ tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5), 
#             tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5') ]

history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 83/83 [==============================] - 38s 452ms/step - loss: 1.9421 - accuracy: 0.4113 - val_loss: 4.9335 - val_accuracy: 0.1027
# Epoch 2/20
# 83/83 [==============================] - 31s 373ms/step - loss: 1.2220 - accuracy: 0.5245 - val_loss: 5.1532 - val_accuracy: 0.0559
# Epoch 3/20
# 83/83 [==============================] - 31s 373ms/step - loss: 1.0510 - accuracy: 0.5808 - val_loss: 3.6701 - val_accuracy: 0.1073
# Epoch 4/20
# 83/83 [==============================] - 31s 379ms/step - loss: 0.8455 - accuracy: 0.6801 - val_loss: 3.5803 - val_accuracy: 0.3021
# Epoch 5/20
# 83/83 [==============================] - 29s 352ms/step - loss: 0.7046 - accuracy: 0.7368 - val_loss: 2.2568 - val_accuracy: 0.3414
# Epoch 6/20
# 83/83 [==============================] - 29s 350ms/step - loss: 0.5237 - accuracy: 0.8089 - val_loss: 2.1074 - val_accuracy: 0.4789
# Epoch 7/20
# 83/83 [==============================] - 29s 354ms/step - loss: 0.4168 - accuracy: 0.8425 - val_loss: 1.9621 - val_accuracy: 0.3973
# Epoch 8/20
# 83/83 [==============================] - 29s 345ms/step - loss: 0.2898 - accuracy: 0.8988 - val_loss: 1.7443 - val_accuracy: 0.5302
# Epoch 9/20
# 83/83 [==============================] - 29s 347ms/step - loss: 0.1832 - accuracy: 0.9343 - val_loss: 2.1452 - val_accuracy: 0.4849
# Epoch 10/20
# 83/83 [==============================] - 33s 389ms/step - loss: 0.0998 - accuracy: 0.9743 - val_loss: 1.7796 - val_accuracy: 0.5725
# Epoch 11/20
# 83/83 [==============================] - 30s 361ms/step - loss: 0.0809 - accuracy: 0.9747 - val_loss: 1.9989 - val_accuracy: 0.5529
# Epoch 12/20
# 83/83 [==============================] - 27s 323ms/step - loss: 0.1092 - accuracy: 0.9603 - val_loss: 2.7085 - val_accuracy: 0.4728
# Epoch 13/20
# 83/83 [==============================] - 27s 327ms/step - loss: 0.0640 - accuracy: 0.9804 - val_loss: 2.4120 - val_accuracy: 0.5393
# Epoch 14/20
# 83/83 [==============================] - 36s 431ms/step - loss: 0.0889 - accuracy: 0.9679 - val_loss: 2.1728 - val_accuracy: 0.5347
# Epoch 15/20
# 83/83 [==============================] - 32s 384ms/step - loss: 0.1388 - accuracy: 0.9566 - val_loss: 2.7697 - val_accuracy: 0.5136
# Epoch 16/20
# 83/83 [==============================] - 28s 336ms/step - loss: 0.1521 - accuracy: 0.9460 - val_loss: 2.4095 - val_accuracy: 0.4789
# Epoch 17/20
# 83/83 [==============================] - 35s 418ms/step - loss: 0.1036 - accuracy: 0.9683 - val_loss: 2.8613 - val_accuracy: 0.4894
# Epoch 18/20
# 83/83 [==============================] - 35s 418ms/step - loss: 0.0713 - accuracy: 0.9728 - val_loss: 3.3169 - val_accuracy: 0.3973
# Epoch 19/20
# 83/83 [==============================] - 31s 373ms/step - loss: 0.0643 - accuracy: 0.9792 - val_loss: 2.7084 - val_accuracy: 0.5106
# Epoch 20/20
# 83/83 [==============================] - 27s 321ms/step - loss: 0.0339 - accuracy: 0.9902 - val_loss: 3.2688 - val_accuracy: 0.4879

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
acc = acc*100
print('Test Accuracy: %.3f' % acc)
# Out:
# Test Accuracy: 48.792

# %%
y_pred = model.predict(X_test)
y_pred_label = np.argmax(y_pred, axis=1)
y_test_label = np.argmax(y_test, axis=1)
# make a bargraph of accuracy per class
from sklearn.metrics import accuracy_score
acc_per_class = []
for i in range(6):
    acc_per_class.append(accuracy_score(y_test_label[y_test_label==i], y_pred_label[y_test_label==i]))

bars  = plt.bar(le.classes_, acc_per_class)
plt.title('Accuracy per class')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval + .005, round(yval,3))
plt.show()
# plt.bar(le.classes_, acc_per_class)
# plt.title('Accuracy per class')
# plt.show()
# Out:
# 21/21 [==============================] - 2s 82ms/step

# %%
model.save('model_contrast.keras')

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.tight_layout()
plt.show()
